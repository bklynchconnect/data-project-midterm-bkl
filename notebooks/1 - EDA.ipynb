# %% [markdown]
# # EDA

# %% [markdown]
# - The os module has a perfect method to list files in a directory.
# - Pandas json normalize could work here but is not necessary to convert the JSON data to a dataframe.
# - You may need a nested for-loop to access each sale!
# - We've put a lot of time into creating the structure of this repository, and it's a good example for future projects.  In the file functions_variables.py, there is an example function that you can import and use.  If you have any variables, functions or classes that you want to make, they can be put in the functions_variables.py file and imported into a notebook.  Note that only .py files can be imported into a notebook. If you want to import everything from a .py file, you can use the following:
# ```python
# from functions_variables import *
# ```
# If you just import functions_variables, then each object from the file will need to be prepended with "functions_variables"\
# Using this .py file will keep your notebooks very organized and make it easier to reuse code between notebooks.

# %%
# (this is not an exhaustive list of libraries)
import pandas as pd
import numpy as np
import os
import json
from pprint import pprint
from functions_variables import encode_tags

# %%
def load_json_file(fname):
    with open(fname,'r') as f:
        data_json = json.load(f)

    df = pd.json_normalize(data_json['data']['results'])

    return df

# %% [markdown]
# ## Data Importing

# %%
# load one file first to see what type of data you're dealing with and what attributes it has
with open('..\\data\\WY_Cheyenne_2.json','r') as f:
    data_json = json.load(f)

# %%
data_json
# Out:
# {'status': 200, 'data': {'total': 0, 'count': 0, 'results': {}}}

# %%
data_json['data'].keys()
# Out:
# dict_keys(['total', 'count', 'results'])

# %%
df = pd.json_normalize(data_json['data']['results'])

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
df = load_json_file('..\\data\\AK_Juneau_1.json')

# %%
df
# Out:
#   primary_photo      last_update_date  source  \
# 0          None                  None     NaN
# 1          None                  None     NaN
# 2          None                  None     NaN
# 3          None                  None     NaN
# 4          None  2023-08-04T22:49:14Z     NaN
# 5          None  2023-08-04T21:31:44Z     NaN
# 6          None            2023-12-07     NaN
#
#                                                 tags  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  [carport, hill_or_mountain_view, ocean_view, s...
# 5  [city_view, community_outdoor_space, community...
# 6                                               None
#
#                                            permalink status  \
# 0  8477-Thunder-Mountain-Rd_Juneau_AK_99801_M9424...   sold
# 1      4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516   sold
# 2  17850-Point-Stephens-Rd_Juneau_AK_99801_M98793...   sold
# 3  9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99...   sold
# 4  11909-Glacier-Hwy-Apt-105_Juneau_AK_99801_M741...   sold
# 5            808-5th-St_Juneau_AK_99801_M76604-90777   sold
# 6    4446-Trafalgar-Ave_Juneau_AK_99801_M82741-21172   sold
#
#                      list_date open_houses  \
# 0                         None        None
# 1                         None        None
# 2                         None        None
# 3                         None        None
# 4  2023-08-21T21:01:22.000000Z        None
# 5  2023-08-21T21:01:22.000000Z        None
# 6                         None        None
#
#                                             branding  list_price  ...  \
# 0  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  ...
# 1  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  ...
# 2  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  ...
# 3  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  ...
# 4  [{'name': 'Platinum Keller Williams Realty Ala...    415000.0  ...
# 5  [{'name': 'Southeast Alaska Real Estate', 'pho...    835000.0  ...
# 6  [{'name': None, 'photo': None, 'type': 'Office'}]         NaN  ...
#
#   location.county.fips_code location.county.name source.plan_id  \
# 0                      None               Juneau            NaN
# 1                      None               Juneau            NaN
# 2                      None               Juneau            NaN
# 3                      None               Juneau            NaN
# 4                      None               Juneau            NaN
# 5                      None               Juneau            NaN
# 6                      None               Juneau            NaN
#
#                                        source.agents source.spec_id  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4  [{'office_name': 'Platinum Keller Williams Rea...            NaN
# 5  [{'office_name': 'Southeast Alaska Real Estate...            NaN
# 6                                                NaN            NaN
#
#   source.type products.brand_name  location.address.coordinate.lon  \
# 0         NaN                 NaN                              NaN
# 1         NaN                 NaN                              NaN
# 2         NaN                 NaN                              NaN
# 3         NaN                 NaN                              NaN
# 4         mls        basic_opt_in                      -134.649067
# 5         mls          essentials                      -134.403991
# 6         NaN                 NaN                      -134.553717
#
#    location.address.coordinate.lat other_listings
# 0                              NaN            NaN
# 1                              NaN            NaN
# 2                              NaN            NaN
# 3                              NaN            NaN
# 4                        58.386651            NaN
# 5                        58.304573            NaN
# 6                        58.396178            NaN
#
# [7 rows x 63 columns]

# %%
f = '123.png'
f[-4:]
# Out:
# '.png'

# %%
# loop over all files and put them into a dataframe
from os import listdir
from os.path import join, isfile

data_dir = '..\\data'
f = '123.png'
os.path.join(data_dir,f)

file_list = []
for f in listdir(data_dir):
    if isfile(join(data_dir,f)) and f[-5:] == '.json':
        print(f"adding {f}")
        file_list.append(join(data_dir,f))
    else:
        print(f"ignoring {f}")
# Out:
# ignoring .gitkeep
# adding AK_Juneau_0.json
# ignoring AK_Juneau_1.5_dir_.json
# adding AK_Juneau_1.json
# adding AK_Juneau_2.json
# adding AK_Juneau_3.json
# adding AK_Juneau_4.json
# adding AL_Montgomery_0.json
# adding AL_Montgomery_1.json
# adding AL_Montgomery_2.json
# adding AL_Montgomery_3.json
# adding AL_Montgomery_4.json
# adding AR_LittleRock_0.json
# adding AR_LittleRock_1.json
# adding AR_LittleRock_2.json
# adding AR_LittleRock_3.json
# adding AR_LittleRock_4.json
# adding AZ_Phoenix_0.json
# adding AZ_Phoenix_1.json
# adding AZ_Phoenix_2.json
# adding AZ_Phoenix_3.json
# adding AZ_Phoenix_4.json
# adding CA_Sacramento_0.json
# adding CA_Sacramento_1.json
# adding CA_Sacramento_2.json
# adding CA_Sacramento_3.json
# adding CA_Sacramento_4.json
# adding CO_Denver_0.json
# adding CO_Denver_1.json
# adding CO_Denver_2.json
# adding CO_Denver_3.json
# adding CO_Denver_4.json
# adding CT_Hartford_0.json
# adding CT_Hartford_1.json
# adding CT_Hartford_2.json
# adding CT_Hartford_3.json
# adding CT_Hartford_4.json
# adding DE_Dover_0.json
# adding DE_Dover_1.json
# adding DE_Dover_2.json
# adding DE_Dover_3.json
# adding DE_Dover_4.json
# adding FL_Tallahassee_0.json
# adding FL_Tallahassee_1.json
# adding FL_Tallahassee_2.json
# adding FL_Tallahassee_3.json
# adding FL_Tallahassee_4.json
# adding GA_Atlanta_0.json
# adding GA_Atlanta_1.json
# adding GA_Atlanta_2.json
# adding GA_Atlanta_3.json
# adding GA_Atlanta_4.json
# adding HI_Honolulu_0.json
# adding HI_Honolulu_1.json
# adding HI_Honolulu_2.json
# adding NM_SantaFe_0.json
# adding NM_SantaFe_1.json
# adding NM_SantaFe_2.json
# adding NM_SantaFe_3.json
# adding NM_SantaFe_4.json
# adding NV_CarsonCity_0.json
# adding NV_CarsonCity_1.json
# adding NV_CarsonCity_2.json
# adding NV_CarsonCity_3.json
# adding NV_CarsonCity_4.json
# adding NY_Albany_0.json
# adding NY_Albany_1.json
# adding NY_Albany_2.json
# adding NY_Albany_3.json
# adding NY_Albany_4.json
# adding OH_Columbus_0.json
# adding OH_Columbus_1.json
# adding OH_Columbus_2.json
# adding OH_Columbus_3.json
# adding OH_Columbus_4.json
# adding OK_OklahomaCity_0.json
# adding OK_OklahomaCity_1.json
# adding OK_OklahomaCity_2.json
# adding OK_OklahomaCity_3.json
# adding OK_OklahomaCity_4.json
# adding OR_Salem_0.json
# adding OR_Salem_1.json
# adding OR_Salem_2.json
# adding OR_Salem_3.json
# adding OR_Salem_4.json
# adding PA_Harrisburg_0.json
# adding PA_Harrisburg_1.json
# adding PA_Harrisburg_2.json
# adding PA_Harrisburg_3.json
# adding PA_Harrisburg_4.json
# adding RI_Providence_0.json
# adding RI_Providence_1.json
# adding RI_Providence_2.json
# adding RI_Providence_3.json
# adding RI_Providence_4.json
# adding SC_Columbia_0.json
# adding SC_Columbia_1.json
# adding SC_Columbia_2.json
# adding SC_Columbia_3.json
# adding SC_Columbia_4.json
# adding SD_Pierre_0.json
# adding SD_Pierre_1.json
# adding SD_Pierre_2.json
# adding SD_Pierre_3.json
# adding SD_Pierre_4.json
# adding TN_Nashville_0.json
# adding TN_Nashville_1.json
# adding TN_Nashville_2.json
# adding TN_Nashville_3.json
# adding TN_Nashville_4.json
# adding TX_Austin_0.json
# adding TX_Austin_1.json
# adding TX_Austin_2.json
# adding TX_Austin_3.json
# adding TX_Austin_4.json
# adding UT_SaltLakeCity_0.json
# adding UT_SaltLakeCity_1.json
# adding UT_SaltLakeCity_2.json
# adding UT_SaltLakeCity_3.json
# adding UT_SaltLakeCity_4.json
# adding VA_Richmond_0.json
# adding VA_Richmond_1.json
# adding VA_Richmond_2.json
# adding VA_Richmond_3.json
# adding VA_Richmond_4.json
# adding VT_Montpelier_0.json
# adding VT_Montpelier_1.json
# adding VT_Montpelier_2.json
# adding VT_Montpelier_3.json
# adding VT_Montpelier_4.json
# adding WA_Olympia_0.json
# adding WA_Olympia_1.json
# adding WA_Olympia_2.json
# adding WA_Olympia_3.json
# adding WA_Olympia_4.json
# adding WI_Madison_0.json
# adding WI_Madison_1.json
# adding WI_Madison_2.json
# adding WI_Madison_3.json
# adding WI_Madison_4.json
# adding WV_Charleston_0.json
# adding WV_Charleston_1.json
# adding WV_Charleston_2.json
# adding WV_Charleston_3.json
# adding WV_Charleston_4.json
# adding WY_Cheyenne_0.json
# adding WY_Cheyenne_1.json
# adding WY_Cheyenne_2.json
# adding WY_Cheyenne_3.json
# adding WY_Cheyenne_4.json

# %%
file_list = [f for f in listdir(data_dir) if isfile(join(data_dir,f)) and f[-5:] == '.json']

# %%
df = pd.DataFrame()

for file_name in file_list:
    df_temp = load_json_file(file_name)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#           last_update_date                                               tags  \
# 0     2023-09-19T20:52:50Z  [carport, community_outdoor_space, cul_de_sac,...
# 1                     None                                               None
# 2                     None                                               None
# 3                     None                                               None
# 4                     None                                               None
# ...                    ...                                                ...
# 8186                   NaN                                                NaN
# 8187                   NaN                                                NaN
# 8188                   NaN                                                NaN
# 8189                   NaN                                                NaN
# 8190                   NaN                                                NaN
#
#                                               permalink status  \
# 0          9453-Herbert-Pl_Juneau_AK_99801_M90744-30767   sold
# 1     8477-Thunder-Mountain-Rd_Juneau_AK_99801_M9424...   sold
# 2         4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516   sold
# 3     17850-Point-Stephens-Rd_Juneau_AK_99801_M98793...   sold
# 4     9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99...   sold
# ...                                                 ...    ...
# 8186                                                NaN    NaN
# 8187                                                NaN    NaN
# 8188                                                NaN    NaN
# 8189                                                NaN    NaN
# 8190                                                NaN    NaN
#
#                         list_date open_houses  \
# 0     2023-06-29T21:16:25.000000Z        None
# 1                            None        None
# 2                            None        None
# 3                            None        None
# 4                            None        None
# ...                           ...         ...
# 8186                          NaN        None
# 8187                          NaN        None
# 8188                          NaN        None
# 8189                          NaN        None
# 8190                          NaN        None
#
#                                                branding  list_price  \
# 0     [{'name': 'EXP Realty LLC - Southeast Alaska',...    554950.0
# 1     [{'name': None, 'photo': None, 'type': 'Office'}]         NaN
# 2     [{'name': None, 'photo': None, 'type': 'Office'}]         NaN
# 3     [{'name': None, 'photo': None, 'type': 'Office'}]         NaN
# 4     [{'name': None, 'photo': None, 'type': 'Office'}]         NaN
# ...                                                 ...         ...
# 8186                                                NaN         NaN
# 8187                                                NaN         NaN
# 8188                                                NaN         NaN
# 8189                                                NaN         NaN
# 8190                                                NaN         NaN
#
#      property_id                                             photos  ...  \
# 0     9074430767  [{'tags': [{'label': 'house_view', 'probabilit...  ...
# 1     9424983842                                               None  ...
# 2     9479068516                                               None  ...
# 3     9879331943                                               None  ...
# 4     9521639574                                               None  ...
# ...          ...                                                ...  ...
# 8186         NaN                                                NaN  ...
# 8187         NaN                                                NaN  ...
# 8188         NaN                                                NaN  ...
# 8189         NaN                                                NaN  ...
# 8190         NaN                                                NaN  ...
#
#      location.county.fips_code location.county.name primary_photo  source  \
# 0                         None               Juneau           NaN     NaN
# 1                         None               Juneau           NaN     NaN
# 2                         None               Juneau           NaN     NaN
# 3                         None               Juneau           NaN     NaN
# 4                         None               Juneau           NaN     NaN
# ...                        ...                  ...           ...     ...
# 8186                       NaN                  NaN           NaN     NaN
# 8187                       NaN                  NaN           NaN     NaN
# 8188                       NaN                  NaN           NaN     NaN
# 8189                       NaN                  NaN           NaN     NaN
# 8190                       NaN                  NaN           NaN     NaN
#
#      products location.address.coordinate other_listings  \
# 0         NaN                         NaN            NaN
# 1         NaN                         NaN            NaN
# 2         NaN                         NaN            NaN
# 3         NaN                         NaN            NaN
# 4         NaN                         NaN            NaN
# ...       ...                         ...            ...
# 8186      NaN                         NaN            NaN
# 8187      NaN                         NaN            NaN
# 8188      NaN                         NaN            NaN
# 8189      NaN                         NaN            NaN
# 8190      NaN                         NaN            NaN
#
#      community.advertisers community.description.name location.county
# 0                      NaN                        NaN             NaN
# 1                      NaN                        NaN             NaN
# 2                      NaN                        NaN             NaN
# 3                      NaN                        NaN             NaN
# 4                      NaN                        NaN             NaN
# ...                    ...                        ...             ...
# 8186                   NaN                        NaN             NaN
# 8187                   NaN                        NaN             NaN
# 8188                   NaN                        NaN             NaN
# 8189                   NaN                        NaN             NaN
# 8190                   NaN                        NaN             NaN
#
# [8191 rows x 67 columns]

# %% [markdown]
# ## Data Cleaning and Wrangling

# %% [markdown]
# At this point, ensure that you have all sales in a dataframe.
# - Take a quick look at your data (i.e. `.info()`, `.describe()`) - what do you see?
# - Is each cell one value, or do some cells have lists?
# - What are the data types of each column?
# - Some sales may not actually include the sale price (target).  These rows should be dropped.
# - There are a lot of NA/None values.  Should these be dropped or replaced with something?
#     - You can drop rows or use various methods to fills NA's - use your best judgement for each column
#     - i.e. for some columns (like Garage), NA probably just means no Garage, so 0
# - Drop columns that aren't needed
#     - Don't keep the list price because it will be too close to the sale price. Assume we want to predict the price of houses not yet listed

# %%
# load and concatenate data here
# drop or replace values as necessary

# %% [markdown]
# ### Dealing with Tags

# %% [markdown]
# Consider the fact that with tags, there are a lot of categorical variables.
# - How many columns would we have if we OHE tags, city and state?
# - Perhaps we can get rid of tags that have a low frequency.

# %%
# OHE categorical variables/ tags here
# tags will have to be done manually

# %% [markdown]
# ### Dealing with Cities

# %% [markdown]
# - Sales will vary drastically between cities and states.  Is there a way to keep information about which city it is without OHE?
# - Could we label encode or ordinal encode?  Yes, but this may have undesirable effects, giving nominal data ordinal values.
# - What we can do is use our training data to encode the mean sale price by city as a feature (a.k.a. Target Encoding)
#     - We can do this as long as we ONLY use the training data - we're using the available data to give us a 'starting guess' of the price for each city, without needing to encode city explicitly
# - If you replace cities or states with numerical values (like the mean price), make sure that the data is split so that we don't leak data into the training selection. This is a great time to train test split. Compute on the training data, and join these values to the test data
# - Note that you *may* have cities in the test set that are not in the training set. You don't want these to be NA, so maybe you can fill them with the overall mean

# %%
# perform train test split here
# do something with state and city

# %% [markdown]
# ## Extra Data - STRETCH
#
# > This doesn't need to be part of your Minimum Viable Product (MVP). We recommend you write a functional, basic pipeline first, then circle back and join new data if you have time
#
# > If you do this, try to write your downstream steps in a way it will still work on a dataframe with different features!
#
# - You're not limited to just using the data provided to you. Think/ do some research about other features that might be useful to predict housing prices.
# - Can you import and join this data? Make sure you do any necessary preprocessing and make sure it is joined correctly.
# - Example suggestion: could mortgage interest rates in the year of the listing affect the price?

# %%
# import, join and preprocess new data here

# %% [markdown]
# ## EDA/ Visualization
#
# Remember all of the EDA that you've been learning about?  Now is a perfect time for it!
# - Look at distributions of numerical variables to see the shape of the data and detect outliers.
#     - Consider transforming very skewed variables
# - Scatterplots of a numerical variable and the target go a long way to show correlations.
# - A heatmap will help detect highly correlated features, and we don't want these.
#     - You may have too many features to do this, in which case you can simply compute the most correlated feature-pairs and list them
# - Is there any overlap in any of the features? (redundant information, like number of this or that room...)

# %%
# perform EDA here

# %% [markdown]
# ## Scaling and Finishing Up

# %% [markdown]
# Now is a great time to scale the data and save it once it's preprocessed.
# - You can save it in your data folder, but you may want to make a new `processed/` subfolder to keep it organized
